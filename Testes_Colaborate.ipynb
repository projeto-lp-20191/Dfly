# %% [markdown]
# <a href="https://colab.research.google.com/github/projeto-lp-20191/pandas/blob/master/Testes_Colaborate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive 
drive.mount('/content/gdrive')

# %%
fatores=pd.read_csv('gdrive/My Drive/Material BSI/LP/Material Projeto/Ocorrencias/ftc.csv', sep='~')
fatores

# %%
fatores_clima = fatores.loc[(fatores['fator_nome'])=='CONDIÇÕES METEOROLÓGICAS ADVERSAS']
fatores_tratada = fatores_clima.iloc[:,[0,1,5]].drop_duplicates()
fatores_tratada

# %%
ocorrencias=pd.read_csv('gdrive/My Drive/Material BSI/LP/Material Projeto/Ocorrencias/oco.csv', sep='~')
ocorrencias_sudeste = ocorrencias.loc[ocorrencias['ocorrencia_uf'].isin(['ES','MG','RJ','SP'])]
ocorrencias_tratada = ocorrencias_sudeste.iloc[:,[0,1,2,3,5,6,7,8,11,12]].drop_duplicates()

# %%
ocorrencias_clima = pd.merge(fatores_tratada, ocorrencias_tratada, on = 'codigo_ocorrencia', how='left')
ocorrencias_clima
# Out:
#      codigo_ocorrencia                         fator_nome  \
# 0      200801112101167  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 1      200801159627220  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 2      200801235808261  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 3      200802118201345  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 4      200802236257231  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 5      200802265376981  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 6      200803319171733  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 7      200804099230817  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 8      200804195711783  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 9      200804303594333  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 10     200805029668770  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 11     200808052216995  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 12     200811016390336  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 13     200811075237787  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 14     200812089521613  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# ...
